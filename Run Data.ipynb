# %%
import pandas as pd

# %%
raras = pd.read_csv('activities.csv')
pd.pandas.set_option('display.max_columns', None)
raras.head(5)
# Out:
#    Activity ID              Activity Date Activity Name Activity Type  \
# 0   6377159038  Dec 13, 2021, 12:41:36 AM   Morning Run           Run
# 1   6380706014  Dec 13, 2021, 11:23:56 PM   Morning Run           Run
# 2   6380758451  Dec 13, 2021, 11:39:00 PM   Morning Run           Run
# 3   6389055797  Dec 15, 2021, 11:43:47 PM   Morning Run           Run
# 4   6396531978  Dec 18, 2021, 12:15:03 AM   Morning Run           Run
#
#   Activity Description  Elapsed Time  Distance  Max Heart Rate  \
# 0                  NaN           540      1.14           173.0
# 1                  NaN           547      1.19           176.0
# 2                  NaN           505      1.00           172.0
# 3                  NaN          2411      4.69           181.0
# 4                  NaN          3912      7.06           185.0
#
#    Relative Effort  Commute  Activity Gear                      Filename  \
# 0             17.0    False            NaN  activities/6778985319.fit.gz
# ...

# %%
import pandas as pd

# %%
angga = pd.read_csv('activities angga.csv')
angga.head(5)
# Out:
#    Activity ID              Activity Date Activity Name Activity Type  \
# 0   1797573105  Aug 25, 2018, 11:25:13 PM          SMTR           Run
# 1   1813008368   Sep 1, 2018, 11:36:04 PM   Morning Run           Run
# 2   1833385460  Sep 11, 2018, 12:19:59 AM   Morning Run           Run
# 3   1844199436  Sep 16, 2018, 12:09:55 AM   Morning Run           Run
# 4   1859441800  Sep 22, 2018, 11:38:30 PM   Morning Run           Run
#
#   Activity Description  Elapsed Time  Distance  Max Heart Rate  \
# 0                  NaN         10592     23.01             NaN
# 1                  NaN          3855      9.12             NaN
# 2                  NaN          3002      6.38             NaN
# 3                  NaN          4508      9.66             NaN
# 4                  NaN          4276      8.98             NaN
#
#    Relative Effort  Commute  Activity Gear                   Filename  \
# 0              NaN    False            NaN  activities/1797573105.gpx
# ...

# %%
all = pd.read_excel('ALL.xlsx')
all.head(5)
# Out:
#    Activity ID              Activity Date         Time Activity Name  \
# 0   1797573105  Aug 25, 2018, 11:25:13 PM  11:25:13 PM          SMTR
# 1   1813008368   Sep 1, 2018, 11:36:04 PM  11:36:04 PM   Morning Run
# 2   1833385460  Sep 11, 2018, 12:19:59 AM  12:19:59 AM   Morning Run
# 3   1844199436  Sep 16, 2018, 12:09:55 AM  12:09:55 AM   Morning Run
# 4   1859441800  Sep 22, 2018, 11:38:30 PM  11:38:30 PM   Morning Run
#
#   Activity Type Activity Description  Distance (km)  Max Heart Rate  \
# 0           Run                  NaN          23.01             NaN
# 1           Run                  NaN           9.12             NaN
# 2           Run                  NaN           6.38             NaN
# 3           Run                  NaN           9.66             NaN
# 4           Run                  NaN           8.98             NaN
#
#    Relative Effort                   Filename  Athlete Weight  \
# 0              NaN  activities/1797573105.gpx             0.0
# ...

# %%
import pandas as pd
import numpy as np
import json
import re
import datetime
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns

# %%
all["Activity Date"] = pd.to_datetime(all["Activity Date"], errors = 'coerce')
all["Activity Date"] = all["Activity Date"].dt.date

# %%
all.head(5)
# Out:
#    Activity ID Activity Date         Time Activity Name Activity Type  \
# 0   1797573105    2018-08-25  11:25:13 PM          SMTR           Run
# 1   1813008368    2018-09-01  11:36:04 PM   Morning Run           Run
# 2   1833385460    2018-09-11  12:19:59 AM   Morning Run           Run
# 3   1844199436    2018-09-16  12:09:55 AM   Morning Run           Run
# 4   1859441800    2018-09-22  11:38:30 PM   Morning Run           Run
#
#   Activity Description  Distance (km)  Max Heart Rate  Relative Effort  \
# 0                  NaN          23.01             NaN              NaN
# 1                  NaN           9.12             NaN              NaN
# 2                  NaN           6.38             NaN              NaN
# 3                  NaN           9.66             NaN              NaN
# 4                  NaN           8.98             NaN              NaN
#
#                     Filename  Athlete Weight  Elapsed Time (seconds)  \
# ...

# %%
all.to_csv('databenar.csv')
